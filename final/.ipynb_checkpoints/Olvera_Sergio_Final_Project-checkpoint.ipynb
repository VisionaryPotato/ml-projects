# %% [markdown]
# # Intoduction
# For my final project, I'm going to implement two different machine learining approaches to see how they differ from one another.
# From this, I hope to draw a conclusion on what approach works best for the dataset.
#
# ## Dataset
# This project will primarly will be using the [scikit-learn diabetes dataset](https://scikit-learn.org/stable/datasets/toy_dataset.html#diabetes-dataset). I will consider this project successful if I could test different machine learning models and identify which model works best and know *why* it works best.

# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from numpy.random import default_rng
from sklearn import datasets # Where our diabetes datasets lives.
from sklearn.model_selection import train_test_split # used for splitting our data
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# # Load Data Set
# This dataset comes from sklearns diabetes dataset. Instead of using the dataset provided by sklearns, I got the [data](https://www4.stat.ncsu.edu/~boos/var.select/diabetes.tab.txt) from the [source](https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html) directly as the data from sklearn was standardized.

# %%
diabetes_data = datasets.load_diabetes()
data = pd.read_csv('diabetes_data.csv')
data.columns = ['age',	'sex',	'bmi',	'bp',	's1',	's2', 's3',	's4',	's5',	's6',	'dp']
data.head()
# Out:
#    age  sex   bmi     bp   s1     s2    s3   s4      s5  s6   dp
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %% [markdown]
# We could take a quick look at the shape of the data just so we could visualize how it's structured, and the correlation coefficients of of the differend feature variables

# %%
data.shape
# Out:
# (442, 11)

# %% [markdown]
# # Data Interpritation
# ### We can see in the shape of the data that there are 442 instances(samples) of data, with 10 feature variables.
#
# ### These feature variables are:
# *   **age:** (in years)
# *   **sex:**
# *   **bmi:**: Body mass index
# *   **bp:** average blood pressure
# *   **s1-tc:** total serum cholesterol
# *   **s2-ldl:** low-density lipoproteiens
# *   **s3-hdl:** high-density lipoproteins
# *   **s4-tch:** total cholesterol / HDL
# *   **s5-ltg:** possibly log of serum triglycerides level
# *   **s6-glu:** blood sugar level
# *   **dp:** Our target data represents the disease progression one year after baseline. This is our variable of interest.

# %% [markdown]
# # Setup
#
# The first two Machine Learning approaches that I will be focusing on this project consist of univariate and multivariate linear regression models. This data set consists of 10 feature variables, so it's important to see the predictions differ in both models. I will then compare the results with a K-Nearest-Neighbors model.
#
# *Note: I will be use Assignment 3 as a reference when building the models as it's a well done exemplar on univariate & mulitvariate regression algorithims.*

# %%
data.corr()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# age  1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# sex  0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# bmi  0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# bp   0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# s1   0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# s2   0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# s3  -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# s4   0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# s5   0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# s6   0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
# dp   0.187889  0.043062  0.586450  0.441482  0.212022  0.174054 -0.394789
#
#            s4        s5        s6        dp
# age  0.203841  0.270774  0.301731  0.187889
# sex  0.332115  0.149916  0.208133  0.043062
# bmi  0.413807  0.446157  0.388680  0.586450
# bp   0.257650  0.393480  0.390430  0.441482
# s1   0.542207  0.515503  0.325717  0.212022
# s2   0.659817  0.318357  0.290600  0.174054
# s3  -0.738493 -0.398577 -0.273697 -0.394789
# s4   1.000000  0.617859  0.417212  0.430453
# s5   0.617859  1.000000  0.464669  0.565883
# s6   0.417212  0.464669  1.000000  0.382483
# dp   0.430453  0.565883  0.382483  1.000000

# %% [markdown]
# As we can see, Body Mass Index and s5 (possibly log of serum triglycerides levels) are highly correlated with the disease progression after a year with the correlation values of 0.586450 and 0.565883 respectively.
#
# For our univariate linear regression model, we will use **BMI** as our feature variable and **dp** as our comparison.
#
# Our first step is to write a function that fits our univariate linear regression model. *
# Note: I will use Assignemt 3 as a reference as the process is similar.*

# %%
def univariate_model(df, feature):
  linear_regression = LinearRegression()
  X = data[[feature]].values #Primarly for, but not limited to, BMI.
  y = data['dp'].values;
  linear_regression.fit(X,y)
  return X, y, linear_regression

# %%
Xp, yp, lrp = univariate_model(data, 'bmi')

# %% [markdown]
# Now that we have this univariate regression model, we could visuallize the regression model by using the generated linear regression model to predict.

# %%
def plot_graph(X, y, lr, xlabel,title):
    x_label = xlabel
    y_label = 'Disease Progression'
    y_pred = lr.predict(X)  # our predicted linear model with respect to X
    fig = plt.figure(figsize=(12,5))
    ax = fig.add_subplot(111)
    ax.scatter(X, y, c="darkgreen")
    ax.plot(X,y_pred,c="darkred") # 'o' reformats the plot to circles instead of lines.
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.set_title(title)
    return None

def plot_regression_result_1(X, y, lr, xlabel):
    y_true = data['dp'].values # Ground truth target values.
    y_pred = lr.predict(X) # our predicted linear model with respect to X
    title = (f'{xlabel} Model with Respect to Disease Progression')
    plot_graph(X, y, lr, xlabel,title);
    return None

# %%
plt.rcParams.update({'font.size': 12})

plot_regression_result_1(Xp, yp, lrp, 'bmi')

# %% [markdown]
# It's important for us to analyze the regression loss of our predicted model. In essense, this will help us justify if linear regression is a viable approach to this dataset.
#
# I'm going to create a function that calculates the mean absolute error & root mean error so we could se

# %%
def round_y(y):# Referenced Assignement 3
# We rounded our regressions in order to get an integer to match with our data.
# This is done so we could calculate a valid regression accuracy.
  return np.round(y) 

def evaluate(X, y, lr):
  y_true = data['dp'].values
  y_pred = lr.predict(X)

  accur = np.sum((round_y(y_pred) == y))/y.shape[0]
  rmse = np.sqrt(mean_squared_error(y_true, y_pred)) # Mean root error regression loss.
  mae = mean_absolute_error(y_true, y_pred) # Mean absolute error regression loss.
  r2 = lr.score(X,y)
  print("The root mean squared error is: %4.2f" % rmse)
  print("The mean absolute error is: %4.2f" % mae)
  print(f'Coefficient of determination(R2): {r2:5.2f}')
  print(f"Accuracy: {accur:5.3f}")

# %%
evaluate(Xp,yp,lrp)
# Out:
# The root mean squared error is: 62.37
# The mean absolute error is: 51.80
# Coefficient of determination(R2):  0.34
# Accuracy: 0.005

# %% [markdown]
# We used such evaluation metrics to make judgement of this linear regression model to compare continuous values. In this case we compared BMI with disease progression.
#
#
# As we can see, our evaluation metrics for our regression models tells us that essentially our BMI regression model can predict the disease progression with an **average error of 51.80**. The mean squared error wasn't that helpful because it punished larger errors, therefore I calculated the root mean squared error as it's easier to understand.
#
# It's important to note that the accuracy on BMI is not good whatsoever. This is to be expected as our error metrics were on average very high; however, we could take a look at the correlation coefficient. We could see that the variance in BMI and disease progression in this linear regression model is only 0.344.
#
#
# *   R2 = 0: Meaning that the model always fails to predict target value
# *   R2 = 1: Meaning that the model perfectly predict target value
#
# We could actually see the different R2 values with the other feature variables.

# %%
def calculate_r2():
  sum = 0;
  r2_scores = []
  for feature in data.columns.drop(['dp']):
      Xa, ya, lra = univariate_model(data, feature)
      y_pred = lra.predict(Xa) # predction model
      r2 = lra.score(Xa,ya)
      r2_scores.append([r2,feature]) # appends accuracy and feature to our accuracies list.

  [print(f"R2 score {r2[0]:5.2f} for feature {r2[1]}") for r2 in r2_scores] # prints our score for each feat.


calculate_r2()
# Out:
# R2 score  0.04 for feature age
# R2 score  0.00 for feature sex
# R2 score  0.34 for feature bmi
# R2 score  0.19 for feature bp
# R2 score  0.04 for feature s1
# R2 score  0.03 for feature s2
# R2 score  0.16 for feature s3
# R2 score  0.19 for feature s4
# R2 score  0.32 for feature s5
# R2 score  0.15 for feature s6

# %% [markdown]
# By looking at these predicted univariate regression r2 models scores, we can tell that the **bmi** and **s5** feature models have the strongest relationship with disease progression.

# %% [markdown]
# ## Generalize with Multivariate Linear Regression
# As we can see, our BMI by it self produces very low accuracies with high error rates. Now let's train our linear regression all of our feature variables.
#
# We're going to start of by creating a function that fits our multiple features.

# %%
def multivariate_model(df):
  X = df[df.columns.drop(['dp'])] # all features except disease progression.
  y = df['dp'] # our target value
  model = LinearRegression();
  model.fit(X,y)
  return X, y, model

# %%
Xm, ym, lrm = multivariate_model(data)

y_pred = np.round(lrm.predict(Xm))
evaluate(Xm,ym,lrm)
# Out:
# The root mean squared error is: 53.48
# The mean absolute error is: 43.28
# Coefficient of determination(R2):  0.52
# Accuracy: 0.009

# %% [markdown]
# Using this dataset, we can determine that,by using sklearn's linear regression model, it's only able to successfuly make "good" predictions 52% of the time when working with multivariate data.

# %% [markdown]
# # K-Nearest-Neighbors Regressor
# Let's implement a K-nearest neighbor algorithm to see if there's a better change in our coefficient determination. This algorithm also allows us to generalize the data, so we'll be able to include all of the 10 features instead of just looking at BMI.

# %% [markdown]
# ## Setup
#
# In order for our knn algorithm to work properly, we need to split the data into two subsets: training & testing.
#
# Due to the nature of the data, I'll have to write a function that does the splitting for us. This function will be utilizing the sklearn.
#
# When splitting this dataset:
#
# *   We're splitting data 50/50.
# *   Random State = 42.

# %%
def split(df,size):
  X = df[df.columns.drop(['dp'])].values # All features except for quality
  y = df['dp'].values
  return train_test_split(X,y,test_size=size,random_state=42)

# %% [markdown]
# Now we could implement the k-nn algorithm and see how the R2 metrics differ in both machine learning models.

# %%
def fit_nearest_neighbor (df, k) : # Reference from Assignment 3.
  X_train, X_test, y_train, y_test = split(df,.5)
  kn = KNeighborsRegressor(n_neighbors=k)
  kn.fit(X_train, y_train) #fit training data
  kn.predict(X_test)
  r2 = kn.score(X_test, y_test)
  print(f'R2 score with {k} neighbors: {r2}')
  return r2

# %%
n_neighbors = 10
r2_scores = []
for i in range(2,n_neighbors+1):
  r2_scores.append(fit_nearest_neighbor(data,i))
# Out:
# R2 score with 2 neighbors: -0.006519383057284278
# R2 score with 3 neighbors: 0.11981877591116574
# R2 score with 4 neighbors: 0.19834762969693387
# R2 score with 5 neighbors: 0.2656803299267305
# R2 score with 6 neighbors: 0.279204634401916
# R2 score with 7 neighbors: 0.2972710658504766
# R2 score with 8 neighbors: 0.2936814524657716
# R2 score with 9 neighbors: 0.29259051585742846
# R2 score with 10 neighbors: 0.28535031686663204

# %%
print(f"Average knn R2 score: {np.mean(r2_scores):5.3f}")
# Out:
# Average knn R2 score: 0.225

# %% [markdown]
# # Neural Network Approach
# ## Import Setup

# %%
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from keras.metrics import MeanAbsoluteError

# !pip install tensorflow-addons # - May need to install this.
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow_addons.metrics import RSquare # add-on metric for rsquare
# Out:
# Requirement already satisfied: tensorflow-addons in /Users/sergioolvera/opt/anaconda3/lib/python3.8/site-packages (0.15.0)
# Requirement already satisfied: typeguard>=2.7 in /Users/sergioolvera/opt/anaconda3/lib/python3.8/site-packages (from tensorflow-addons) (2.13.3)

# %% [markdown]
# As we've previously seen in both our sklearn linear regression model & knn, our coefficient of determination is possibly our best indicator on how well our model is training. As a result, I wanted to collect the R2 metrics in our neural network implementation.

# %% [markdown]
# ## Custom Metric Function
# I found an amazing metric function that calculates R2 metrics when using keras.I will be using this metric to see if our neural network model produces better R2 results.
#
# *Source: https://jmlb.github.io/ml/2017/03/20/CoeffDetermination_CustomMetric4Keras/*
#
# **Update: I'm actually using a [tensorflow add-on](https://www.tensorflow.org/addons/api_docs/python/tfa/metrics/RSquare) that calculates the R2 metrics **

# %%
model_1 = Sequential()
input_size = len(data.columns)-1
model_1.add(Dense(10, input_dim = input_size, kernel_initializer='normal', activation='relu')) # 10 feature variables
model_1.add(Dense(5, activation='relu')) # hidden layer
model_1.add(Dense(1, activation='relu')) # single output

# %% [markdown]
# Our next step is to compile the network. We'll use the Adam optimizer with a the loss function of mean squared error. It would be beneficial to take the metrics of the mean squared error and mean absolute error as it would be useful to compare it against a regular regression model with no regularization.

# %%
loss_fn = keras.losses.MeanSquaredError()
opt = keras.optimizers.Adam()
mae = MeanAbsoluteError()
r_sqr_metric = RSquare(dtype=tf.float32, y_shape=(1,))
# compile network
model_1.compile(loss=loss_fn, optimizer=opt, metrics=[r_sqr_metric, mae])

# %% [markdown]
# Now we can split the data (60% training, 40% test) and finally we will train the neural network with our validation data.

# %%
X_train, X_test, y_train, y_test = split(data,.6)
history = model_1.fit(X_train,y_train,batch_size=5,validation_split=0.6,epochs=1000, validation_data=(X_test, y_test))
# Out:
# Epoch 1/1000
# 14/14 [==============================] - 1s 16ms/step - loss: 29782.6699 - r_square: -3.3821 - mean_absolute_error: 151.5956 - val_loss: 24433.8535 - val_r_square: -3.2470 - val_mean_absolute_error: 136.6800
# Epoch 2/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 28532.1875 - r_square: -3.1982 - mean_absolute_error: 147.4892 - val_loss: 23544.8730 - val_r_square: -3.0925 - val_mean_absolute_error: 133.4485
# Epoch 3/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 27442.2344 - r_square: -3.0378 - mean_absolute_error: 143.9201 - val_loss: 22457.1523 - val_r_square: -2.9035 - val_mean_absolute_error: 129.3665
# Epoch 4/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 26182.1992 - r_square: -2.8524 - mean_absolute_error: 139.5935 - val_loss: 21225.5898 - val_r_square: -2.6894 - val_mean_absolute_error: 124.5886
# Epoch 5/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 24778.9785 - r_square: -2.6459 - mean_absolute_error: 134.5638 - val_loss: 19813.3027 - val_r_square: -2.4439 - val_mean_absolute_error: 118.8764
# Epoch 6/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 23129.9922 - r_square: -2.4033 - mean_absolute_error: 128.6235 - val_loss: 18298.1777 - val_r_square: -2.1805 - val_mean_absolute_error: 112.4525
# Epoch 7/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 21459.5195 - r_square: -2.1575 - mean_absolute_error: 121.6191 - val_loss: 16568.5938 - val_r_square: -1.8799 - val_mean_absolute_error: 104.7400
# Epoch 8/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 19424.2266 - r_square: -1.8580 - mean_absolute_error: 114.1651 - val_loss: 14885.0215 - val_r_square: -1.5873 - val_mean_absolute_error: 96.7285
# Epoch 9/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 17449.9805 - r_square: -1.5675 - mean_absolute_error: 105.9877 - val_loss: 13124.7900 - val_r_square: -1.2813 - val_mean_absolute_error: 88.3145
# Epoch 10/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 15456.8574 - r_square: -1.2743 - mean_absolute_error: 97.8546 - val_loss: 11376.3711 - val_r_square: -0.9774 - val_mean_absolute_error: 80.3927
# Epoch 11/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 13516.7012 - r_square: -0.9888 - mean_absolute_error: 89.2189 - val_loss: 9746.5449 - val_r_square: -0.6941 - val_mean_absolute_error: 73.1452
# Epoch 12/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 11714.9150 - r_square: -0.7237 - mean_absolute_error: 81.8372 - val_loss: 8341.7461 - val_r_square: -0.4499 - val_mean_absolute_error: 67.5313
# Epoch 13/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 10044.0967 - r_square: -0.4779 - mean_absolute_error: 74.0322 - val_loss: 7273.9722 - val_r_square: -0.2643 - val_mean_absolute_error: 64.3135
# Epoch 14/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 8796.6055 - r_square: -0.2943 - mean_absolute_error: 70.0449 - val_loss: 6420.8462 - val_r_square: -0.1161 - val_mean_absolute_error: 61.9898
# Epoch 15/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 7696.2490 - r_square: -0.1324 - mean_absolute_error: 66.7804 - val_loss: 5896.3418 - val_r_square: -0.0249 - val_mean_absolute_error: 61.1209
# Epoch 16/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 6964.0342 - r_square: -0.0247 - mean_absolute_error: 65.2096 - val_loss: 5585.1074 - val_r_square: 0.0292 - val_mean_absolute_error: 61.3290
# Epoch 17/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 6455.4224 - r_square: 0.0502 - mean_absolute_error: 63.8475 - val_loss: 5446.2280 - val_r_square: 0.0533 - val_mean_absolute_error: 61.7984
# Epoch 18/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 6162.1665 - r_square: 0.0933 - mean_absolute_error: 63.3827 - val_loss: 5424.4150 - val_r_square: 0.0571 - val_mean_absolute_error: 62.4316
# Epoch 19/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5960.9922 - r_square: 0.1229 - mean_absolute_error: 63.1101 - val_loss: 5460.8164 - val_r_square: 0.0508 - val_mean_absolute_error: 63.2707
# Epoch 20/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5888.9302 - r_square: 0.1335 - mean_absolute_error: 63.3267 - val_loss: 5526.5171 - val_r_square: 0.0394 - val_mean_absolute_error: 64.1429
# Epoch 21/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5820.0635 - r_square: 0.1437 - mean_absolute_error: 63.4039 - val_loss: 5565.5151 - val_r_square: 0.0326 - val_mean_absolute_error: 64.5680
# Epoch 22/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 5793.4170 - r_square: 0.1476 - mean_absolute_error: 63.4315 - val_loss: 5601.6953 - val_r_square: 0.0263 - val_mean_absolute_error: 64.9096
# Epoch 23/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5783.5337 - r_square: 0.1490 - mean_absolute_error: 63.4666 - val_loss: 5620.3091 - val_r_square: 0.0231 - val_mean_absolute_error: 65.0793
# Epoch 24/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 5765.0469 - r_square: 0.1517 - mean_absolute_error: 63.4218 - val_loss: 5642.9546 - val_r_square: 0.0192 - val_mean_absolute_error: 65.2698
# Epoch 25/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5768.4897 - r_square: 0.1512 - mean_absolute_error: 63.5076 - val_loss: 5693.0078 - val_r_square: 0.0105 - val_mean_absolute_error: 65.6412
# Epoch 26/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5751.3540 - r_square: 0.1538 - mean_absolute_error: 63.4439 - val_loss: 5662.8662 - val_r_square: 0.0157 - val_mean_absolute_error: 65.4405
# Epoch 27/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5741.2339 - r_square: 0.1552 - mean_absolute_error: 63.4164 - val_loss: 5677.5801 - val_r_square: 0.0131 - val_mean_absolute_error: 65.5542
# Epoch 28/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5730.0156 - r_square: 0.1569 - mean_absolute_error: 63.3591 - val_loss: 5660.6367 - val_r_square: 0.0161 - val_mean_absolute_error: 65.4468
# Epoch 29/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 5729.1021 - r_square: 0.1570 - mean_absolute_error: 63.3184 - val_loss: 5640.5288 - val_r_square: 0.0196 - val_mean_absolute_error: 65.3137
# Epoch 30/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5739.4111 - r_square: 0.1555 - mean_absolute_error: 63.2773 - val_loss: 5617.3262 - val_r_square: 0.0236 - val_mean_absolute_error: 65.1548
# Epoch 31/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5713.4927 - r_square: 0.1593 - mean_absolute_error: 63.1784 - val_loss: 5667.7876 - val_r_square: 0.0148 - val_mean_absolute_error: 65.5256
# Epoch 32/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5706.2554 - r_square: 0.1604 - mean_absolute_error: 63.3015 - val_loss: 5692.2275 - val_r_square: 0.0106 - val_mean_absolute_error: 65.7123
# Epoch 33/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5681.5288 - r_square: 0.1640 - mean_absolute_error: 63.1492 - val_loss: 5664.6289 - val_r_square: 0.0154 - val_mean_absolute_error: 65.5300
# Epoch 34/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5673.3369 - r_square: 0.1652 - mean_absolute_error: 63.0481 - val_loss: 5629.2817 - val_r_square: 0.0215 - val_mean_absolute_error: 65.2885
# Epoch 35/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5684.0127 - r_square: 0.1637 - mean_absolute_error: 63.0896 - val_loss: 5571.4810 - val_r_square: 0.0316 - val_mean_absolute_error: 64.8728
# Epoch 36/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5660.9546 - r_square: 0.1671 - mean_absolute_error: 62.8513 - val_loss: 5606.8560 - val_r_square: 0.0254 - val_mean_absolute_error: 65.1505
# Epoch 37/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 5646.6816 - r_square: 0.1692 - mean_absolute_error: 62.9001 - val_loss: 5621.7642 - val_r_square: 0.0228 - val_mean_absolute_error: 65.2679
# Epoch 38/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5636.1855 - r_square: 0.1707 - mean_absolute_error: 62.8446 - val_loss: 5607.2178 - val_r_square: 0.0254 - val_mean_absolute_error: 65.1734
# Epoch 39/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5627.9316 - r_square: 0.1719 - mean_absolute_error: 62.7774 - val_loss: 5618.8042 - val_r_square: 0.0234 - val_mean_absolute_error: 65.2739
# Epoch 40/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5625.9326 - r_square: 0.1722 - mean_absolute_error: 62.7627 - val_loss: 5612.7646 - val_r_square: 0.0244 - val_mean_absolute_error: 65.2431
# Epoch 41/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5614.5640 - r_square: 0.1739 - mean_absolute_error: 62.7185 - val_loss: 5620.1641 - val_r_square: 0.0231 - val_mean_absolute_error: 65.3099
# Epoch 42/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5600.6143 - r_square: 0.1759 - mean_absolute_error: 62.6371 - val_loss: 5573.8643 - val_r_square: 0.0312 - val_mean_absolute_error: 64.9779
# Epoch 43/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5598.2344 - r_square: 0.1763 - mean_absolute_error: 62.5939 - val_loss: 5569.2378 - val_r_square: 0.0320 - val_mean_absolute_error: 64.9564
# Epoch 44/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5575.9634 - r_square: 0.1796 - mean_absolute_error: 62.5015 - val_loss: 5567.9883 - val_r_square: 0.0322 - val_mean_absolute_error: 64.9620
# Epoch 45/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5569.7236 - r_square: 0.1805 - mean_absolute_error: 62.4951 - val_loss: 5589.0352 - val_r_square: 0.0285 - val_mean_absolute_error: 65.1335
# Epoch 46/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5559.8774 - r_square: 0.1819 - mean_absolute_error: 62.4345 - val_loss: 5577.7793 - val_r_square: 0.0305 - val_mean_absolute_error: 65.0635
# Epoch 47/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5567.1675 - r_square: 0.1809 - mean_absolute_error: 62.4057 - val_loss: 5528.8574 - val_r_square: 0.0390 - val_mean_absolute_error: 64.7038
# Epoch 48/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5534.3291 - r_square: 0.1857 - mean_absolute_error: 62.2455 - val_loss: 5554.2139 - val_r_square: 0.0346 - val_mean_absolute_error: 64.9126
# Epoch 49/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5529.9922 - r_square: 0.1863 - mean_absolute_error: 62.2465 - val_loss: 5550.2710 - val_r_square: 0.0353 - val_mean_absolute_error: 64.8977
# Epoch 50/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5523.7832 - r_square: 0.1872 - mean_absolute_error: 62.2211 - val_loss: 5564.6816 - val_r_square: 0.0328 - val_mean_absolute_error: 65.0189
# Epoch 51/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5510.9058 - r_square: 0.1891 - mean_absolute_error: 62.1900 - val_loss: 5568.6509 - val_r_square: 0.0321 - val_mean_absolute_error: 65.0594
# Epoch 52/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5524.7085 - r_square: 0.1871 - mean_absolute_error: 62.3288 - val_loss: 5501.7500 - val_r_square: 0.0437 - val_mean_absolute_error: 64.5660
# Epoch 53/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5499.6943 - r_square: 0.1908 - mean_absolute_error: 62.0591 - val_loss: 5495.8154 - val_r_square: 0.0447 - val_mean_absolute_error: 64.5332
# Epoch 54/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5499.5400 - r_square: 0.1908 - mean_absolute_error: 62.1949 - val_loss: 5575.4336 - val_r_square: 0.0309 - val_mean_absolute_error: 65.1389
# Epoch 55/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5485.8931 - r_square: 0.1928 - mean_absolute_error: 62.0831 - val_loss: 5499.6289 - val_r_square: 0.0441 - val_mean_absolute_error: 64.5945
# Epoch 56/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5464.3203 - r_square: 0.1960 - mean_absolute_error: 61.9003 - val_loss: 5515.2080 - val_r_square: 0.0414 - val_mean_absolute_error: 64.7273
# Epoch 57/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5459.5254 - r_square: 0.1967 - mean_absolute_error: 61.8647 - val_loss: 5491.8086 - val_r_square: 0.0454 - val_mean_absolute_error: 64.5607
# Epoch 58/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5456.9580 - r_square: 0.1971 - mean_absolute_error: 61.9022 - val_loss: 5545.3472 - val_r_square: 0.0361 - val_mean_absolute_error: 64.9689
# Epoch 59/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5459.7188 - r_square: 0.1967 - mean_absolute_error: 62.0538 - val_loss: 5567.2720 - val_r_square: 0.0323 - val_mean_absolute_error: 65.1500
# Epoch 60/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5412.7646 - r_square: 0.2036 - mean_absolute_error: 61.6860 - val_loss: 5501.9033 - val_r_square: 0.0437 - val_mean_absolute_error: 64.6788
# Epoch 61/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5469.0859 - r_square: 0.1953 - mean_absolute_error: 61.9053 - val_loss: 5405.4399 - val_r_square: 0.0604 - val_mean_absolute_error: 63.9215
# Epoch 62/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5406.4482 - r_square: 0.2045 - mean_absolute_error: 61.4833 - val_loss: 5472.5103 - val_r_square: 0.0488 - val_mean_absolute_error: 64.4820
# Epoch 63/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5397.2617 - r_square: 0.2059 - mean_absolute_error: 61.5193 - val_loss: 5499.5820 - val_r_square: 0.0441 - val_mean_absolute_error: 64.6955
# Epoch 64/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5380.0176 - r_square: 0.2084 - mean_absolute_error: 61.4939 - val_loss: 5461.9009 - val_r_square: 0.0506 - val_mean_absolute_error: 64.4269
# Epoch 65/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5377.2163 - r_square: 0.2088 - mean_absolute_error: 61.4405 - val_loss: 5479.8086 - val_r_square: 0.0475 - val_mean_absolute_error: 64.5739
# Epoch 66/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5361.7246 - r_square: 0.2111 - mean_absolute_error: 61.3856 - val_loss: 5452.8174 - val_r_square: 0.0522 - val_mean_absolute_error: 64.3819
# Epoch 67/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5351.9043 - r_square: 0.2125 - mean_absolute_error: 61.3115 - val_loss: 5461.4888 - val_r_square: 0.0507 - val_mean_absolute_error: 64.4602
# Epoch 68/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5350.3730 - r_square: 0.2128 - mean_absolute_error: 61.2484 - val_loss: 5427.8418 - val_r_square: 0.0565 - val_mean_absolute_error: 64.2155
# Epoch 69/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5333.4814 - r_square: 0.2152 - mean_absolute_error: 61.2052 - val_loss: 5445.1431 - val_r_square: 0.0535 - val_mean_absolute_error: 64.3603
# Epoch 70/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5326.1362 - r_square: 0.2163 - mean_absolute_error: 61.1482 - val_loss: 5425.0459 - val_r_square: 0.0570 - val_mean_absolute_error: 64.2195
# Epoch 71/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5314.6064 - r_square: 0.2180 - mean_absolute_error: 61.1188 - val_loss: 5421.3999 - val_r_square: 0.0577 - val_mean_absolute_error: 64.2037
# Epoch 72/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5310.0698 - r_square: 0.2187 - mean_absolute_error: 61.0974 - val_loss: 5428.6182 - val_r_square: 0.0564 - val_mean_absolute_error: 64.2763
# Epoch 73/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5291.3076 - r_square: 0.2215 - mean_absolute_error: 61.0383 - val_loss: 5437.2676 - val_r_square: 0.0549 - val_mean_absolute_error: 64.3659
# Epoch 74/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5282.1743 - r_square: 0.2228 - mean_absolute_error: 60.9049 - val_loss: 5407.7876 - val_r_square: 0.0600 - val_mean_absolute_error: 64.1409
# Epoch 75/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5283.8838 - r_square: 0.2225 - mean_absolute_error: 60.8528 - val_loss: 5369.9512 - val_r_square: 0.0666 - val_mean_absolute_error: 63.8525
# Epoch 76/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5268.7168 - r_square: 0.2248 - mean_absolute_error: 60.8257 - val_loss: 5427.0303 - val_r_square: 0.0567 - val_mean_absolute_error: 64.3436
# Epoch 77/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5259.4668 - r_square: 0.2261 - mean_absolute_error: 60.8559 - val_loss: 5455.2891 - val_r_square: 0.0518 - val_mean_absolute_error: 64.5982
# Epoch 78/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5233.4976 - r_square: 0.2300 - mean_absolute_error: 60.7407 - val_loss: 5399.3726 - val_r_square: 0.0615 - val_mean_absolute_error: 64.1464
# Epoch 79/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5226.8105 - r_square: 0.2309 - mean_absolute_error: 60.6314 - val_loss: 5379.0396 - val_r_square: 0.0650 - val_mean_absolute_error: 63.9935
# Epoch 80/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5239.2266 - r_square: 0.2291 - mean_absolute_error: 60.5726 - val_loss: 5336.4849 - val_r_square: 0.0724 - val_mean_absolute_error: 63.6496
# Epoch 81/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5212.1528 - r_square: 0.2331 - mean_absolute_error: 60.4968 - val_loss: 5376.6079 - val_r_square: 0.0655 - val_mean_absolute_error: 64.0136
# Epoch 82/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5200.9775 - r_square: 0.2347 - mean_absolute_error: 60.4821 - val_loss: 5379.6279 - val_r_square: 0.0649 - val_mean_absolute_error: 64.0622
# Epoch 83/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5196.1802 - r_square: 0.2354 - mean_absolute_error: 60.4394 - val_loss: 5350.2324 - val_r_square: 0.0700 - val_mean_absolute_error: 63.8217
# Epoch 84/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5175.3667 - r_square: 0.2385 - mean_absolute_error: 60.3144 - val_loss: 5340.2300 - val_r_square: 0.0718 - val_mean_absolute_error: 63.7549
# Epoch 85/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5175.2759 - r_square: 0.2385 - mean_absolute_error: 60.3344 - val_loss: 5361.2290 - val_r_square: 0.0681 - val_mean_absolute_error: 63.9637
# Epoch 86/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5165.0854 - r_square: 0.2400 - mean_absolute_error: 60.3115 - val_loss: 5383.6963 - val_r_square: 0.0642 - val_mean_absolute_error: 64.1801
# Epoch 87/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5153.4014 - r_square: 0.2417 - mean_absolute_error: 60.3200 - val_loss: 5362.9336 - val_r_square: 0.0678 - val_mean_absolute_error: 64.0235
# Epoch 88/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 5136.8564 - r_square: 0.2442 - mean_absolute_error: 60.1102 - val_loss: 5328.5200 - val_r_square: 0.0738 - val_mean_absolute_error: 63.7388
# Epoch 89/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5133.5195 - r_square: 0.2447 - mean_absolute_error: 60.0433 - val_loss: 5307.6812 - val_r_square: 0.0774 - val_mean_absolute_error: 63.5711
# Epoch 90/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5114.2983 - r_square: 0.2475 - mean_absolute_error: 59.9843 - val_loss: 5323.4028 - val_r_square: 0.0747 - val_mean_absolute_error: 63.7378
# Epoch 91/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5107.8330 - r_square: 0.2484 - mean_absolute_error: 60.0101 - val_loss: 5339.6655 - val_r_square: 0.0719 - val_mean_absolute_error: 63.9006
# Epoch 92/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 5119.1772 - r_square: 0.2468 - mean_absolute_error: 60.0033 - val_loss: 5268.0171 - val_r_square: 0.0843 - val_mean_absolute_error: 63.2718
# Epoch 93/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5084.8384 - r_square: 0.2518 - mean_absolute_error: 59.7824 - val_loss: 5297.9097 - val_r_square: 0.0791 - val_mean_absolute_error: 63.5722
# Epoch 94/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5080.8159 - r_square: 0.2524 - mean_absolute_error: 59.7870 - val_loss: 5298.0342 - val_r_square: 0.0791 - val_mean_absolute_error: 63.5965
# Epoch 95/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5120.3115 - r_square: 0.2466 - mean_absolute_error: 59.9619 - val_loss: 5244.7378 - val_r_square: 0.0884 - val_mean_absolute_error: 63.1185
# Epoch 96/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5044.9741 - r_square: 0.2577 - mean_absolute_error: 59.5471 - val_loss: 5286.6772 - val_r_square: 0.0811 - val_mean_absolute_error: 63.5376
# Epoch 97/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5052.1309 - r_square: 0.2566 - mean_absolute_error: 59.7269 - val_loss: 5317.2847 - val_r_square: 0.0758 - val_mean_absolute_error: 63.8271
# Epoch 98/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5048.2627 - r_square: 0.2572 - mean_absolute_error: 59.6655 - val_loss: 5279.1821 - val_r_square: 0.0824 - val_mean_absolute_error: 63.5146
# Epoch 99/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5044.8525 - r_square: 0.2577 - mean_absolute_error: 59.6353 - val_loss: 5341.2842 - val_r_square: 0.0716 - val_mean_absolute_error: 64.0594
# Epoch 100/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5015.5562 - r_square: 0.2620 - mean_absolute_error: 59.5885 - val_loss: 5304.0391 - val_r_square: 0.0781 - val_mean_absolute_error: 63.7689
# Epoch 101/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 5004.0942 - r_square: 0.2637 - mean_absolute_error: 59.3678 - val_loss: 5250.2549 - val_r_square: 0.0874 - val_mean_absolute_error: 63.3137
# Epoch 102/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4992.8403 - r_square: 0.2654 - mean_absolute_error: 59.2975 - val_loss: 5236.6782 - val_r_square: 0.0898 - val_mean_absolute_error: 63.2108
# Epoch 103/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4988.9526 - r_square: 0.2659 - mean_absolute_error: 59.3057 - val_loss: 5248.5967 - val_r_square: 0.0877 - val_mean_absolute_error: 63.3411
# Epoch 104/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4980.5420 - r_square: 0.2672 - mean_absolute_error: 59.3318 - val_loss: 5275.5117 - val_r_square: 0.0830 - val_mean_absolute_error: 63.5968
# Epoch 105/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4965.8037 - r_square: 0.2693 - mean_absolute_error: 59.2677 - val_loss: 5264.8770 - val_r_square: 0.0849 - val_mean_absolute_error: 63.5239
# Epoch 106/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4950.2119 - r_square: 0.2716 - mean_absolute_error: 59.1682 - val_loss: 5233.5728 - val_r_square: 0.0903 - val_mean_absolute_error: 63.2672
# Epoch 107/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4940.9771 - r_square: 0.2730 - mean_absolute_error: 59.0416 - val_loss: 5219.7197 - val_r_square: 0.0927 - val_mean_absolute_error: 63.1625
# Epoch 108/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4962.1167 - r_square: 0.2699 - mean_absolute_error: 59.0523 - val_loss: 5154.4819 - val_r_square: 0.1041 - val_mean_absolute_error: 62.5881
# Epoch 109/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4918.4302 - r_square: 0.2763 - mean_absolute_error: 58.7650 - val_loss: 5191.2549 - val_r_square: 0.0977 - val_mean_absolute_error: 62.9563
# Epoch 110/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4909.1851 - r_square: 0.2777 - mean_absolute_error: 58.8271 - val_loss: 5215.6709 - val_r_square: 0.0934 - val_mean_absolute_error: 63.1862
# Epoch 111/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4912.9707 - r_square: 0.2771 - mean_absolute_error: 58.9582 - val_loss: 5227.3232 - val_r_square: 0.0914 - val_mean_absolute_error: 63.3058
# Epoch 112/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4886.8237 - r_square: 0.2810 - mean_absolute_error: 58.7937 - val_loss: 5195.1021 - val_r_square: 0.0970 - val_mean_absolute_error: 63.0509
# Epoch 113/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 4877.6562 - r_square: 0.2823 - mean_absolute_error: 58.7452 - val_loss: 5200.5928 - val_r_square: 0.0960 - val_mean_absolute_error: 63.1155
# Epoch 114/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4864.7524 - r_square: 0.2842 - mean_absolute_error: 58.6321 - val_loss: 5181.8550 - val_r_square: 0.0993 - val_mean_absolute_error: 62.9760
# Epoch 115/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4881.8286 - r_square: 0.2817 - mean_absolute_error: 58.5647 - val_loss: 5143.0039 - val_r_square: 0.1061 - val_mean_absolute_error: 62.6509
# Epoch 116/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4843.3062 - r_square: 0.2874 - mean_absolute_error: 58.4095 - val_loss: 5159.9087 - val_r_square: 0.1031 - val_mean_absolute_error: 62.8230
# Epoch 117/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4834.0596 - r_square: 0.2887 - mean_absolute_error: 58.4429 - val_loss: 5194.4238 - val_r_square: 0.0971 - val_mean_absolute_error: 63.1335
# Epoch 118/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4833.4541 - r_square: 0.2888 - mean_absolute_error: 58.5756 - val_loss: 5216.4546 - val_r_square: 0.0933 - val_mean_absolute_error: 63.3248
# Epoch 119/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4817.8857 - r_square: 0.2911 - mean_absolute_error: 58.4755 - val_loss: 5189.9092 - val_r_square: 0.0979 - val_mean_absolute_error: 63.1300
# Epoch 120/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4809.4214 - r_square: 0.2924 - mean_absolute_error: 58.3071 - val_loss: 5126.3184 - val_r_square: 0.1090 - val_mean_absolute_error: 62.6093
# Epoch 121/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4804.1484 - r_square: 0.2931 - mean_absolute_error: 58.3519 - val_loss: 5179.1763 - val_r_square: 0.0998 - val_mean_absolute_error: 63.0744
# Epoch 122/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4788.0269 - r_square: 0.2955 - mean_absolute_error: 58.1527 - val_loss: 5119.4692 - val_r_square: 0.1101 - val_mean_absolute_error: 62.5908
# Epoch 123/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 4770.9307 - r_square: 0.2980 - mean_absolute_error: 58.0182 - val_loss: 5136.1050 - val_r_square: 0.1073 - val_mean_absolute_error: 62.7509
# Epoch 124/1000
# 14/14 [==============================] - 0s 10ms/step - loss: 4765.5376 - r_square: 0.2988 - mean_absolute_error: 58.0284 - val_loss: 5115.1143 - val_r_square: 0.1109 - val_mean_absolute_error: 62.5940
# Epoch 125/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 4752.1152 - r_square: 0.3008 - mean_absolute_error: 57.9149 - val_loss: 5104.2949 - val_r_square: 0.1128 - val_mean_absolute_error: 62.5216
# Epoch 126/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 4741.5474 - r_square: 0.3023 - mean_absolute_error: 57.8519 - val_loss: 5101.9819 - val_r_square: 0.1132 - val_mean_absolute_error: 62.5199
# Epoch 127/1000
# 14/14 [==============================] - 0s 10ms/step - loss: 4728.3457 - r_square: 0.3043 - mean_absolute_error: 57.8082 - val_loss: 5114.3174 - val_r_square: 0.1110 - val_mean_absolute_error: 62.6405
# Epoch 128/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 4713.0933 - r_square: 0.3065 - mean_absolute_error: 57.7906 - val_loss: 5127.2280 - val_r_square: 0.1088 - val_mean_absolute_error: 62.7584
# Epoch 129/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4715.8604 - r_square: 0.3061 - mean_absolute_error: 57.7722 - val_loss: 5106.8838 - val_r_square: 0.1123 - val_mean_absolute_error: 62.6153
# Epoch 130/1000
# 14/14 [==============================] - 0s 10ms/step - loss: 4714.7568 - r_square: 0.3063 - mean_absolute_error: 57.7925 - val_loss: 5169.3882 - val_r_square: 0.1015 - val_mean_absolute_error: 63.1169
# Epoch 131/1000
# 14/14 [==============================] - 0s 10ms/step - loss: 4686.7251 - r_square: 0.3104 - mean_absolute_error: 57.7498 - val_loss: 5121.9775 - val_r_square: 0.1097 - val_mean_absolute_error: 62.7636
# Epoch 132/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 4676.4976 - r_square: 0.3119 - mean_absolute_error: 57.5710 - val_loss: 5079.6626 - val_r_square: 0.1171 - val_mean_absolute_error: 62.4447
# Epoch 133/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 4666.1875 - r_square: 0.3134 - mean_absolute_error: 57.4534 - val_loss: 5058.0112 - val_r_square: 0.1208 - val_mean_absolute_error: 62.2805
# Epoch 134/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 4669.3765 - r_square: 0.3130 - mean_absolute_error: 57.3089 - val_loss: 5026.3418 - val_r_square: 0.1263 - val_mean_absolute_error: 62.0244
# Epoch 135/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 4636.1499 - r_square: 0.3178 - mean_absolute_error: 57.1669 - val_loss: 5039.9297 - val_r_square: 0.1240 - val_mean_absolute_error: 62.1635
# Epoch 136/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 4622.0962 - r_square: 0.3199 - mean_absolute_error: 57.1609 - val_loss: 5063.1128 - val_r_square: 0.1199 - val_mean_absolute_error: 62.3737
# Epoch 137/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 4630.1069 - r_square: 0.3187 - mean_absolute_error: 57.2520 - val_loss: 5044.3296 - val_r_square: 0.1232 - val_mean_absolute_error: 62.2348
# Epoch 138/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4622.1797 - r_square: 0.3199 - mean_absolute_error: 57.2505 - val_loss: 5100.9536 - val_r_square: 0.1134 - val_mean_absolute_error: 62.6943
# Epoch 139/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4595.2246 - r_square: 0.3239 - mean_absolute_error: 57.1667 - val_loss: 5054.8062 - val_r_square: 0.1214 - val_mean_absolute_error: 62.3508
# Epoch 140/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4591.3760 - r_square: 0.3244 - mean_absolute_error: 57.0072 - val_loss: 5053.0791 - val_r_square: 0.1217 - val_mean_absolute_error: 62.3505
# Epoch 141/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4576.7163 - r_square: 0.3266 - mean_absolute_error: 56.9856 - val_loss: 5064.1914 - val_r_square: 0.1198 - val_mean_absolute_error: 62.4513
# Epoch 142/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4561.2212 - r_square: 0.3289 - mean_absolute_error: 56.9194 - val_loss: 5048.1260 - val_r_square: 0.1225 - val_mean_absolute_error: 62.3392
# Epoch 143/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4559.0347 - r_square: 0.3292 - mean_absolute_error: 56.8538 - val_loss: 5008.8506 - val_r_square: 0.1294 - val_mean_absolute_error: 62.0354
# Epoch 144/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4539.2524 - r_square: 0.3321 - mean_absolute_error: 56.6572 - val_loss: 4976.0054 - val_r_square: 0.1351 - val_mean_absolute_error: 61.7698
# Epoch 145/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 4533.2476 - r_square: 0.3330 - mean_absolute_error: 56.5820 - val_loss: 4988.9912 - val_r_square: 0.1328 - val_mean_absolute_error: 61.8983
# Epoch 146/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 4533.8696 - r_square: 0.3329 - mean_absolute_error: 56.6831 - val_loss: 5037.3657 - val_r_square: 0.1244 - val_mean_absolute_error: 62.3030
# Epoch 147/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4502.2539 - r_square: 0.3375 - mean_absolute_error: 56.5321 - val_loss: 4992.5928 - val_r_square: 0.1322 - val_mean_absolute_error: 61.9584
# Epoch 148/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4496.1113 - r_square: 0.3385 - mean_absolute_error: 56.4527 - val_loss: 4994.2578 - val_r_square: 0.1319 - val_mean_absolute_error: 61.9860
# Epoch 149/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4503.0581 - r_square: 0.3374 - mean_absolute_error: 56.3631 - val_loss: 4943.0933 - val_r_square: 0.1408 - val_mean_absolute_error: 61.5617
# Epoch 150/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4484.1973 - r_square: 0.3402 - mean_absolute_error: 56.2326 - val_loss: 4923.1792 - val_r_square: 0.1443 - val_mean_absolute_error: 61.3957
# Epoch 151/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4458.6382 - r_square: 0.3440 - mean_absolute_error: 56.0661 - val_loss: 4941.9482 - val_r_square: 0.1410 - val_mean_absolute_error: 61.5839
# Epoch 152/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4473.7266 - r_square: 0.3417 - mean_absolute_error: 56.4233 - val_loss: 4992.3779 - val_r_square: 0.1322 - val_mean_absolute_error: 62.0166
# Epoch 153/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4442.5273 - r_square: 0.3463 - mean_absolute_error: 56.1582 - val_loss: 4991.2842 - val_r_square: 0.1324 - val_mean_absolute_error: 62.0182
# Epoch 154/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4486.7285 - r_square: 0.3398 - mean_absolute_error: 56.2368 - val_loss: 4889.8931 - val_r_square: 0.1500 - val_mean_absolute_error: 61.1573
# Epoch 155/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4416.3848 - r_square: 0.3502 - mean_absolute_error: 55.7691 - val_loss: 4939.5762 - val_r_square: 0.1414 - val_mean_absolute_error: 61.6210
# Epoch 156/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4449.6094 - r_square: 0.3453 - mean_absolute_error: 56.1967 - val_loss: 5046.8022 - val_r_square: 0.1228 - val_mean_absolute_error: 62.4477
# Epoch 157/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4394.7549 - r_square: 0.3534 - mean_absolute_error: 55.9192 - val_loss: 4972.6929 - val_r_square: 0.1357 - val_mean_absolute_error: 61.9103
# Epoch 158/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4409.0415 - r_square: 0.3513 - mean_absolute_error: 56.0612 - val_loss: 4965.4482 - val_r_square: 0.1369 - val_mean_absolute_error: 61.8624
# Epoch 159/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4376.3892 - r_square: 0.3561 - mean_absolute_error: 55.6177 - val_loss: 4899.9546 - val_r_square: 0.1483 - val_mean_absolute_error: 61.3320
# Epoch 160/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4370.5312 - r_square: 0.3569 - mean_absolute_error: 55.4947 - val_loss: 4874.2295 - val_r_square: 0.1528 - val_mean_absolute_error: 61.1145
# Epoch 161/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4349.4399 - r_square: 0.3600 - mean_absolute_error: 55.3764 - val_loss: 4899.1465 - val_r_square: 0.1484 - val_mean_absolute_error: 61.3501
# Epoch 162/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4338.0308 - r_square: 0.3617 - mean_absolute_error: 55.3800 - val_loss: 4898.6597 - val_r_square: 0.1485 - val_mean_absolute_error: 61.3570
# Epoch 163/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4327.7212 - r_square: 0.3632 - mean_absolute_error: 55.2636 - val_loss: 4878.6367 - val_r_square: 0.1520 - val_mean_absolute_error: 61.1956
# Epoch 164/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4321.4214 - r_square: 0.3642 - mean_absolute_error: 55.1639 - val_loss: 4882.9478 - val_r_square: 0.1513 - val_mean_absolute_error: 61.2453
# Epoch 165/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4315.9189 - r_square: 0.3650 - mean_absolute_error: 55.3534 - val_loss: 4920.0010 - val_r_square: 0.1448 - val_mean_absolute_error: 61.5582
# Epoch 166/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4307.5210 - r_square: 0.3662 - mean_absolute_error: 55.3218 - val_loss: 4882.3887 - val_r_square: 0.1514 - val_mean_absolute_error: 61.2600
# Epoch 167/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4281.1724 - r_square: 0.3701 - mean_absolute_error: 54.9972 - val_loss: 4870.4082 - val_r_square: 0.1534 - val_mean_absolute_error: 61.1666
# Epoch 168/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4279.5688 - r_square: 0.3703 - mean_absolute_error: 54.8994 - val_loss: 4857.3403 - val_r_square: 0.1557 - val_mean_absolute_error: 61.0637
# Epoch 169/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4258.8564 - r_square: 0.3734 - mean_absolute_error: 54.8911 - val_loss: 4878.2949 - val_r_square: 0.1521 - val_mean_absolute_error: 61.2492
# Epoch 170/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4250.1279 - r_square: 0.3746 - mean_absolute_error: 54.8718 - val_loss: 4876.5845 - val_r_square: 0.1524 - val_mean_absolute_error: 61.2420
# Epoch 171/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4249.0151 - r_square: 0.3748 - mean_absolute_error: 54.8794 - val_loss: 4899.7354 - val_r_square: 0.1483 - val_mean_absolute_error: 61.4312
# Epoch 172/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4223.7168 - r_square: 0.3785 - mean_absolute_error: 54.6749 - val_loss: 4867.2007 - val_r_square: 0.1540 - val_mean_absolute_error: 61.1774
# Epoch 173/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4211.6670 - r_square: 0.3803 - mean_absolute_error: 54.5122 - val_loss: 4833.3257 - val_r_square: 0.1599 - val_mean_absolute_error: 60.8991
# Epoch 174/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4208.1396 - r_square: 0.3808 - mean_absolute_error: 54.4316 - val_loss: 4785.2905 - val_r_square: 0.1682 - val_mean_absolute_error: 60.4709
# Epoch 175/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4231.5181 - r_square: 0.3774 - mean_absolute_error: 54.6133 - val_loss: 4847.1611 - val_r_square: 0.1575 - val_mean_absolute_error: 61.0291
# Epoch 176/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4197.0293 - r_square: 0.3825 - mean_absolute_error: 54.3510 - val_loss: 4826.7295 - val_r_square: 0.1610 - val_mean_absolute_error: 60.8636
# Epoch 177/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4187.7378 - r_square: 0.3838 - mean_absolute_error: 54.1976 - val_loss: 4778.7954 - val_r_square: 0.1694 - val_mean_absolute_error: 60.4426
# Epoch 178/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 4159.9355 - r_square: 0.3879 - mean_absolute_error: 54.1140 - val_loss: 4823.9736 - val_r_square: 0.1615 - val_mean_absolute_error: 60.8500
# Epoch 179/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4148.8203 - r_square: 0.3896 - mean_absolute_error: 54.0034 - val_loss: 4789.4043 - val_r_square: 0.1675 - val_mean_absolute_error: 60.5565
# Epoch 180/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4132.1436 - r_square: 0.3920 - mean_absolute_error: 53.9083 - val_loss: 4798.5518 - val_r_square: 0.1659 - val_mean_absolute_error: 60.6431
# Epoch 181/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4128.9302 - r_square: 0.3925 - mean_absolute_error: 53.9291 - val_loss: 4817.7651 - val_r_square: 0.1626 - val_mean_absolute_error: 60.8090
# Epoch 182/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4133.6899 - r_square: 0.3918 - mean_absolute_error: 54.0305 - val_loss: 4823.6426 - val_r_square: 0.1616 - val_mean_absolute_error: 60.8584
# Epoch 183/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4108.6655 - r_square: 0.3955 - mean_absolute_error: 53.7092 - val_loss: 4765.9771 - val_r_square: 0.1716 - val_mean_absolute_error: 60.3708
# Epoch 184/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4094.2200 - r_square: 0.3976 - mean_absolute_error: 53.5958 - val_loss: 4770.2549 - val_r_square: 0.1708 - val_mean_absolute_error: 60.4134
# Epoch 185/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4095.4849 - r_square: 0.3974 - mean_absolute_error: 53.7057 - val_loss: 4823.3379 - val_r_square: 0.1616 - val_mean_absolute_error: 60.8559
# Epoch 186/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4071.2075 - r_square: 0.4010 - mean_absolute_error: 53.5782 - val_loss: 4809.1279 - val_r_square: 0.1641 - val_mean_absolute_error: 60.7426
# Epoch 187/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4056.7290 - r_square: 0.4031 - mean_absolute_error: 53.4425 - val_loss: 4766.5454 - val_r_square: 0.1715 - val_mean_absolute_error: 60.3893
# Epoch 188/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 4051.6013 - r_square: 0.4039 - mean_absolute_error: 53.2228 - val_loss: 4735.8955 - val_r_square: 0.1768 - val_mean_absolute_error: 60.1196
# Epoch 189/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4038.2720 - r_square: 0.4058 - mean_absolute_error: 53.0986 - val_loss: 4720.5337 - val_r_square: 0.1795 - val_mean_absolute_error: 59.9819
# Epoch 190/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4051.0776 - r_square: 0.4039 - mean_absolute_error: 53.1399 - val_loss: 4701.4209 - val_r_square: 0.1828 - val_mean_absolute_error: 59.8030
# Epoch 191/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4029.0894 - r_square: 0.4072 - mean_absolute_error: 53.1516 - val_loss: 4807.2974 - val_r_square: 0.1644 - val_mean_absolute_error: 60.7139
# Epoch 192/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4011.6008 - r_square: 0.4097 - mean_absolute_error: 53.1687 - val_loss: 4740.6924 - val_r_square: 0.1760 - val_mean_absolute_error: 60.1692
# Epoch 193/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 4068.7188 - r_square: 0.4013 - mean_absolute_error: 53.0629 - val_loss: 4649.3804 - val_r_square: 0.1919 - val_mean_absolute_error: 59.2841
# Epoch 194/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 3961.9785 - r_square: 0.4170 - mean_absolute_error: 52.6235 - val_loss: 4728.9102 - val_r_square: 0.1780 - val_mean_absolute_error: 60.0647
# Epoch 195/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 3962.8728 - r_square: 0.4169 - mean_absolute_error: 52.7444 - val_loss: 4780.4395 - val_r_square: 0.1691 - val_mean_absolute_error: 60.4850
# Epoch 196/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 3960.1978 - r_square: 0.4173 - mean_absolute_error: 52.7256 - val_loss: 4758.3687 - val_r_square: 0.1729 - val_mean_absolute_error: 60.3048
# Epoch 197/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 3960.0264 - r_square: 0.4173 - mean_absolute_error: 52.7363 - val_loss: 4786.7861 - val_r_square: 0.1680 - val_mean_absolute_error: 60.5194
# Epoch 198/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 3935.8857 - r_square: 0.4209 - mean_absolute_error: 52.5980 - val_loss: 4735.3340 - val_r_square: 0.1769 - val_mean_absolute_error: 60.1056
# Epoch 199/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 3933.6133 - r_square: 0.4212 - mean_absolute_error: 52.3850 - val_loss: 4666.9189 - val_r_square: 0.1888 - val_mean_absolute_error: 59.4931
# Epoch 200/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 3914.4941 - r_square: 0.4240 - mean_absolute_error: 52.2036 - val_loss: 4697.0693 - val_r_square: 0.1836 - val_mean_absolute_error: 59.7695
# Epoch 201/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 3907.4456 - r_square: 0.4251 - mean_absolute_error: 52.2130 - val_loss: 4702.5474 - val_r_square: 0.1826 - val_mean_absolute_error: 59.8124
# Epoch 202/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 3890.8164 - r_square: 0.4275 - mean_absolute_error: 52.0385 - val_loss: 4689.6099 - val_r_square: 0.1849 - val_mean_absolute_error: 59.6947
# Epoch 203/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 3882.1553 - r_square: 0.4288 - mean_absolute_error: 52.0049 - val_loss: 4684.1436 - val_r_square: 0.1858 - val_mean_absolute_error: 59.6410
# Epoch 204/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 3887.4651 - r_square: 0.4280 - mean_absolute_error: 51.9088 - val_loss: 4646.1436 - val_r_square: 0.1924 - val_mean_absolute_error: 59.2864
# Epoch 205/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 3868.5701 - r_square: 0.4308 - mean_absolute_error: 51.9362 - val_loss: 4687.6753 - val_r_square: 0.1852 - val_mean_absolute_error: 59.6593
# Epoch 206/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 3847.3469 - r_square: 0.4339 - mean_absolute_error: 51.7322 - val_loss: 4693.2749 - val_r_square: 0.1842 - val_mean_absolute_error: 59.6990
# Epoch 207/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 3846.6934 - r_square: 0.4340 - mean_absolute_error: 51.6929 - val_loss: 4651.6553 - val_r_square: 0.1915 - val_mean_absolute_error: 59.3245
# Epoch 208/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 3832.9241 - r_square: 0.4360 - mean_absolute_error: 51.5134 - val_loss: 4643.9580 - val_r_square: 0.1928 - val_mean_absolute_error: 59.2474
# Epoch 209/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 3821.1240 - r_square: 0.4378 - mean_absolute_error: 51.4707 - val_loss: 4689.0010 - val_r_square: 0.1850 - val_mean_absolute_error: 59.6338
# Epoch 210/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 3822.7000 - r_square: 0.4375 - mean_absolute_error: 51.4575 - val_loss: 4654.0303 - val_r_square: 0.1910 - val_mean_absolute_error: 59.3225
# Epoch 211/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 3812.1553 - r_square: 0.4391 - mean_absolute_error: 51.3263 - val_loss: 4636.4688 - val_r_square: 0.1941 - val_mean_absolute_error: 59.1539
# Epoch 212/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 3805.9983 - r_square: 0.4400 - mean_absolute_error: 51.3775 - val_loss: 4652.9712 - val_r_square: 0.1912 - val_mean_absolute_error: 59.2924
# Epoch 213/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 3789.2295 - r_square: 0.4425 - mean_absolute_error: 51.3156 - val_loss: 4699.3828 - val_r_square: 0.1832 - val_mean_absolute_error: 59.6675
# Epoch 214/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 3762.9602 - r_square: 0.4463 - mean_absolute_error: 51.0324 - val_loss: 4648.5176 - val_r_square: 0.1920 - val_mean_absolute_error: 59.2300
# Epoch 215/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 3765.2004 - r_square: 0.4460 - mean_absolute_error: 51.0036 - val_loss: 4650.9072 - val_r_square: 0.1916 - val_mean_absolute_error: 59.2367
# Epoch 216/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 3784.5598 - r_square: 0.4431 - mean_absolute_error: 51.0137 - val_loss: 4564.7959 - val_r_square: 0.2066 - val_mean_absolute_error: 58.4063
# Epoch 217/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 3750.8147 - r_square: 0.4481 - mean_absolute_error: 50.8568 - val_loss: 4633.5850 - val_r_square: 0.1946 - val_mean_absolute_error: 59.0593
# Epoch 218/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 3726.6965 - r_square: 0.4517 - mean_absolute_error: 50.6919 - val_loss: 4645.9893 - val_r_square: 0.1924 - val_mean_absolute_error: 59.1527
# Epoch 219/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 3711.9412 - r_square: 0.4538 - mean_absolute_error: 50.5014 - val_loss: 4619.8203 - val_r_square: 0.1970 - val_mean_absolute_error: 58.9110
# Epoch 220/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 3712.3567 - r_square: 0.4538 - mean_absolute_error: 50.4519 - val_loss: 4587.7100 - val_r_square: 0.2026 - val_mean_absolute_error: 58.6009
# Epoch 221/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 3711.9321 - r_square: 0.4538 - mean_absolute_error: 50.5508 - val_loss: 4639.9321 - val_r_square: 0.1935 - val_mean_absolute_error: 59.0526
# Epoch 222/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 3689.1079 - r_square: 0.4572 - mean_absolute_error: 50.3722 - val_loss: 4606.5225 - val_r_square: 0.1993 - val_mean_absolute_error: 58.7440
# Epoch 223/1000
# ...
# Epoch 927/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2451.9973 - r_square: 0.6392 - mean_absolute_error: 40.8937 - val_loss: 4082.9009 - val_r_square: 0.2903 - val_mean_absolute_error: 53.2347
# Epoch 928/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2460.1101 - r_square: 0.6380 - mean_absolute_error: 40.7582 - val_loss: 4113.0396 - val_r_square: 0.2851 - val_mean_absolute_error: 53.4019
# Epoch 929/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2447.3818 - r_square: 0.6399 - mean_absolute_error: 40.6489 - val_loss: 4102.8140 - val_r_square: 0.2869 - val_mean_absolute_error: 53.3586
# Epoch 930/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2458.7520 - r_square: 0.6382 - mean_absolute_error: 41.0174 - val_loss: 4074.1890 - val_r_square: 0.2918 - val_mean_absolute_error: 53.2105
# Epoch 931/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 2460.7393 - r_square: 0.6379 - mean_absolute_error: 40.8880 - val_loss: 4075.1191 - val_r_square: 0.2917 - val_mean_absolute_error: 53.1617
# Epoch 932/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2461.9185 - r_square: 0.6378 - mean_absolute_error: 40.6464 - val_loss: 4083.8518 - val_r_square: 0.2902 - val_mean_absolute_error: 53.2219
# Epoch 933/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2456.2434 - r_square: 0.6386 - mean_absolute_error: 40.8435 - val_loss: 4077.6660 - val_r_square: 0.2912 - val_mean_absolute_error: 53.2029
# Epoch 934/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2450.7986 - r_square: 0.6394 - mean_absolute_error: 40.7931 - val_loss: 4094.7717 - val_r_square: 0.2883 - val_mean_absolute_error: 53.2974
# Epoch 935/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2454.6033 - r_square: 0.6388 - mean_absolute_error: 40.7546 - val_loss: 4076.0969 - val_r_square: 0.2915 - val_mean_absolute_error: 53.1798
# Epoch 936/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2470.8225 - r_square: 0.6364 - mean_absolute_error: 40.8760 - val_loss: 4116.3931 - val_r_square: 0.2845 - val_mean_absolute_error: 53.4256
# Epoch 937/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2456.0933 - r_square: 0.6386 - mean_absolute_error: 40.8681 - val_loss: 4063.8184 - val_r_square: 0.2936 - val_mean_absolute_error: 53.1169
# Epoch 938/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2467.9097 - r_square: 0.6369 - mean_absolute_error: 40.8700 - val_loss: 4078.0425 - val_r_square: 0.2912 - val_mean_absolute_error: 53.1866
# Epoch 939/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2458.9104 - r_square: 0.6382 - mean_absolute_error: 40.7529 - val_loss: 4109.1533 - val_r_square: 0.2858 - val_mean_absolute_error: 53.3716
# Epoch 940/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2452.2119 - r_square: 0.6392 - mean_absolute_error: 40.7302 - val_loss: 4089.4395 - val_r_square: 0.2892 - val_mean_absolute_error: 53.2807
# Epoch 941/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2477.7766 - r_square: 0.6354 - mean_absolute_error: 40.9707 - val_loss: 4084.0459 - val_r_square: 0.2901 - val_mean_absolute_error: 53.2270
# Epoch 942/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2456.3296 - r_square: 0.6386 - mean_absolute_error: 40.8007 - val_loss: 4093.6880 - val_r_square: 0.2884 - val_mean_absolute_error: 53.2958
# Epoch 943/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2446.6057 - r_square: 0.6400 - mean_absolute_error: 40.7647 - val_loss: 4075.2700 - val_r_square: 0.2916 - val_mean_absolute_error: 53.1715
# Epoch 944/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2468.3997 - r_square: 0.6368 - mean_absolute_error: 40.7175 - val_loss: 4114.4062 - val_r_square: 0.2848 - val_mean_absolute_error: 53.3986
# Epoch 945/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2456.1506 - r_square: 0.6386 - mean_absolute_error: 40.6815 - val_loss: 4074.5623 - val_r_square: 0.2918 - val_mean_absolute_error: 53.1758
# Epoch 946/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2449.4705 - r_square: 0.6396 - mean_absolute_error: 40.8168 - val_loss: 4064.8442 - val_r_square: 0.2935 - val_mean_absolute_error: 53.1135
# Epoch 947/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2451.1624 - r_square: 0.6393 - mean_absolute_error: 40.8143 - val_loss: 4069.4431 - val_r_square: 0.2927 - val_mean_absolute_error: 53.1463
# Epoch 948/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2450.7251 - r_square: 0.6394 - mean_absolute_error: 40.7085 - val_loss: 4099.1011 - val_r_square: 0.2875 - val_mean_absolute_error: 53.3182
# Epoch 949/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2453.5559 - r_square: 0.6390 - mean_absolute_error: 40.8363 - val_loss: 4103.4946 - val_r_square: 0.2867 - val_mean_absolute_error: 53.3434
# Epoch 950/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2447.5168 - r_square: 0.6399 - mean_absolute_error: 40.6800 - val_loss: 4088.6990 - val_r_square: 0.2893 - val_mean_absolute_error: 53.2611
# Epoch 951/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2458.2878 - r_square: 0.6383 - mean_absolute_error: 40.8933 - val_loss: 4055.7788 - val_r_square: 0.2950 - val_mean_absolute_error: 53.0532
# Epoch 952/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2485.2581 - r_square: 0.6343 - mean_absolute_error: 40.8050 - val_loss: 4110.0576 - val_r_square: 0.2856 - val_mean_absolute_error: 53.3549
# Epoch 953/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2486.5381 - r_square: 0.6341 - mean_absolute_error: 41.0344 - val_loss: 4073.6206 - val_r_square: 0.2919 - val_mean_absolute_error: 53.1782
# Epoch 954/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2446.6157 - r_square: 0.6400 - mean_absolute_error: 40.6566 - val_loss: 4054.7358 - val_r_square: 0.2952 - val_mean_absolute_error: 53.0299
# Epoch 955/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2452.7747 - r_square: 0.6391 - mean_absolute_error: 40.6372 - val_loss: 4090.3699 - val_r_square: 0.2890 - val_mean_absolute_error: 53.2624
# Epoch 956/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2473.8499 - r_square: 0.6360 - mean_absolute_error: 41.0860 - val_loss: 4086.6248 - val_r_square: 0.2897 - val_mean_absolute_error: 53.2544
# Epoch 957/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2446.7322 - r_square: 0.6400 - mean_absolute_error: 40.6589 - val_loss: 4092.8066 - val_r_square: 0.2886 - val_mean_absolute_error: 53.2590
# Epoch 958/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2467.5100 - r_square: 0.6369 - mean_absolute_error: 40.7725 - val_loss: 4050.4661 - val_r_square: 0.2960 - val_mean_absolute_error: 53.0025
# Epoch 959/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2484.9875 - r_square: 0.6344 - mean_absolute_error: 40.7095 - val_loss: 4115.4712 - val_r_square: 0.2847 - val_mean_absolute_error: 53.3354
# Epoch 960/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2449.5874 - r_square: 0.6396 - mean_absolute_error: 40.5792 - val_loss: 4070.4028 - val_r_square: 0.2925 - val_mean_absolute_error: 53.1476
# Epoch 961/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2448.2280 - r_square: 0.6398 - mean_absolute_error: 40.7570 - val_loss: 4101.2119 - val_r_square: 0.2871 - val_mean_absolute_error: 53.3236
# Epoch 962/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2440.7087 - r_square: 0.6409 - mean_absolute_error: 40.6269 - val_loss: 4083.0010 - val_r_square: 0.2903 - val_mean_absolute_error: 53.2140
# Epoch 963/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 2450.2358 - r_square: 0.6395 - mean_absolute_error: 40.6416 - val_loss: 4101.8276 - val_r_square: 0.2870 - val_mean_absolute_error: 53.3197
# Epoch 964/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2448.6694 - r_square: 0.6397 - mean_absolute_error: 40.7000 - val_loss: 4061.4824 - val_r_square: 0.2940 - val_mean_absolute_error: 53.0964
# Epoch 965/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2446.8062 - r_square: 0.6400 - mean_absolute_error: 40.7468 - val_loss: 4057.3442 - val_r_square: 0.2948 - val_mean_absolute_error: 53.0540
# Epoch 966/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2433.7859 - r_square: 0.6419 - mean_absolute_error: 40.5603 - val_loss: 4078.9856 - val_r_square: 0.2910 - val_mean_absolute_error: 53.1770
# Epoch 967/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2447.7068 - r_square: 0.6399 - mean_absolute_error: 40.5748 - val_loss: 4112.5479 - val_r_square: 0.2852 - val_mean_absolute_error: 53.3762
# Epoch 968/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2457.0771 - r_square: 0.6385 - mean_absolute_error: 40.6529 - val_loss: 4053.9844 - val_r_square: 0.2953 - val_mean_absolute_error: 53.0385
# Epoch 969/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2454.5830 - r_square: 0.6388 - mean_absolute_error: 40.8785 - val_loss: 4102.8540 - val_r_square: 0.2869 - val_mean_absolute_error: 53.3561
# Epoch 970/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2443.6819 - r_square: 0.6404 - mean_absolute_error: 40.6965 - val_loss: 4088.9363 - val_r_square: 0.2893 - val_mean_absolute_error: 53.2422
# Epoch 971/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2454.2227 - r_square: 0.6389 - mean_absolute_error: 40.7166 - val_loss: 4122.0186 - val_r_square: 0.2835 - val_mean_absolute_error: 53.4569
# Epoch 972/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2434.0615 - r_square: 0.6419 - mean_absolute_error: 40.5519 - val_loss: 4058.3215 - val_r_square: 0.2946 - val_mean_absolute_error: 53.0543
# Epoch 973/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2453.5474 - r_square: 0.6390 - mean_absolute_error: 40.8188 - val_loss: 4048.4600 - val_r_square: 0.2963 - val_mean_absolute_error: 52.9823
# Epoch 974/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2434.3730 - r_square: 0.6418 - mean_absolute_error: 40.5425 - val_loss: 4081.6763 - val_r_square: 0.2905 - val_mean_absolute_error: 53.1671
# Epoch 975/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2455.8159 - r_square: 0.6387 - mean_absolute_error: 40.5298 - val_loss: 4049.9949 - val_r_square: 0.2960 - val_mean_absolute_error: 52.9854
# Epoch 976/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2450.7651 - r_square: 0.6394 - mean_absolute_error: 40.7078 - val_loss: 4110.2554 - val_r_square: 0.2856 - val_mean_absolute_error: 53.3969
# Epoch 977/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2443.9766 - r_square: 0.6404 - mean_absolute_error: 40.8195 - val_loss: 4103.3091 - val_r_square: 0.2868 - val_mean_absolute_error: 53.3746
# Epoch 978/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2446.1274 - r_square: 0.6401 - mean_absolute_error: 40.7056 - val_loss: 4090.0625 - val_r_square: 0.2891 - val_mean_absolute_error: 53.2371
# Epoch 979/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2433.6826 - r_square: 0.6419 - mean_absolute_error: 40.5839 - val_loss: 4055.9395 - val_r_square: 0.2950 - val_mean_absolute_error: 53.0304
# Epoch 980/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2453.4309 - r_square: 0.6390 - mean_absolute_error: 40.6347 - val_loss: 4103.6494 - val_r_square: 0.2867 - val_mean_absolute_error: 53.3448
# Epoch 981/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2437.6479 - r_square: 0.6413 - mean_absolute_error: 40.5992 - val_loss: 4060.4812 - val_r_square: 0.2942 - val_mean_absolute_error: 53.0715
# Epoch 982/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2431.4363 - r_square: 0.6422 - mean_absolute_error: 40.5682 - val_loss: 4085.9905 - val_r_square: 0.2898 - val_mean_absolute_error: 53.2147
# Epoch 983/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2433.5371 - r_square: 0.6419 - mean_absolute_error: 40.6130 - val_loss: 4078.1609 - val_r_square: 0.2911 - val_mean_absolute_error: 53.1759
# Epoch 984/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2439.1340 - r_square: 0.6411 - mean_absolute_error: 40.5112 - val_loss: 4074.1738 - val_r_square: 0.2918 - val_mean_absolute_error: 53.1159
# Epoch 985/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2438.8440 - r_square: 0.6412 - mean_absolute_error: 40.5429 - val_loss: 4089.1062 - val_r_square: 0.2892 - val_mean_absolute_error: 53.2674
# Epoch 986/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2473.6968 - r_square: 0.6360 - mean_absolute_error: 41.1571 - val_loss: 4046.6379 - val_r_square: 0.2966 - val_mean_absolute_error: 52.9795
# Epoch 987/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2474.4001 - r_square: 0.6359 - mean_absolute_error: 40.6993 - val_loss: 4141.9834 - val_r_square: 0.2800 - val_mean_absolute_error: 53.4740
# Epoch 988/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2472.3491 - r_square: 0.6362 - mean_absolute_error: 40.7838 - val_loss: 4048.3577 - val_r_square: 0.2963 - val_mean_absolute_error: 52.9797
# Epoch 989/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2443.2683 - r_square: 0.6405 - mean_absolute_error: 40.6214 - val_loss: 4094.6165 - val_r_square: 0.2883 - val_mean_absolute_error: 53.2809
# Epoch 990/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2446.8960 - r_square: 0.6400 - mean_absolute_error: 40.5993 - val_loss: 4097.6128 - val_r_square: 0.2878 - val_mean_absolute_error: 53.3044
# Epoch 991/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2472.8684 - r_square: 0.6361 - mean_absolute_error: 40.8218 - val_loss: 4029.9124 - val_r_square: 0.2995 - val_mean_absolute_error: 52.8329
# Epoch 992/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 2444.7986 - r_square: 0.6403 - mean_absolute_error: 40.7765 - val_loss: 4087.8462 - val_r_square: 0.2895 - val_mean_absolute_error: 53.2546
# Epoch 993/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 2441.8877 - r_square: 0.6407 - mean_absolute_error: 40.6996 - val_loss: 4082.0598 - val_r_square: 0.2905 - val_mean_absolute_error: 53.1841
# Epoch 994/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2428.3984 - r_square: 0.6427 - mean_absolute_error: 40.4485 - val_loss: 4075.9050 - val_r_square: 0.2915 - val_mean_absolute_error: 53.1713
# Epoch 995/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2438.0330 - r_square: 0.6413 - mean_absolute_error: 40.7712 - val_loss: 4070.6543 - val_r_square: 0.2924 - val_mean_absolute_error: 53.1436
# Epoch 996/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2440.8020 - r_square: 0.6409 - mean_absolute_error: 40.7536 - val_loss: 4105.7080 - val_r_square: 0.2864 - val_mean_absolute_error: 53.3489
# Epoch 997/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2430.1404 - r_square: 0.6424 - mean_absolute_error: 40.4454 - val_loss: 4069.9705 - val_r_square: 0.2926 - val_mean_absolute_error: 53.1108
# Epoch 998/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2435.2170 - r_square: 0.6417 - mean_absolute_error: 40.6831 - val_loss: 4081.7341 - val_r_square: 0.2905 - val_mean_absolute_error: 53.2120
# Epoch 999/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2429.6438 - r_square: 0.6425 - mean_absolute_error: 40.5647 - val_loss: 4084.9399 - val_r_square: 0.2900 - val_mean_absolute_error: 53.2166
# Epoch 1000/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 2441.2449 - r_square: 0.6408 - mean_absolute_error: 40.5373 - val_loss: 4053.3708 - val_r_square: 0.2955 - val_mean_absolute_error: 53.0170

# %%
def plot_metrics(metric_name, title,ylim=1):
  plt.title(title)
  plt.ylim(-1,ylim)
  plt.plot(history.history[metric_name],color='blue',label=metric_name)
  plt.plot(history.history['val_' + metric_name],color='green',label='val_' + metric_name)
  plt.legend()

plot_metrics("r_square", "R Squared");

# %% [markdown]
# # Conclusion
#
#
#
# By using these two machine learning approaches with this dataset, I was able to see how good -or not so good- the machine learning models did when trying to predict the target value. For this dataset, It would be more appropiate to use a linear regression model instead of a KNN model. We saw that the R2 score on the multivariate linear regression model was higher than the average, of up to 10, k-nn. I was mostly focused on the coefficient of correlation as the accuracy for this dataset was very low with a high error rate, so I created an instance of a Neural Network model. I primarly wanted to see if creating and training a neural network to solve this linear-regression dataset could further improve our results. I was glad to see that the model does improve the over-all relationship between our trained models and our variable of interest. All though, I would still to a non-neural-network implementation of a linear regression model as neural model is a bit too complex (and I assume resource intensive) just for an extra ~10% better R2 score predictions. It was an amazing experience applying these models to make decisions about real-world problems such as diabetes.
